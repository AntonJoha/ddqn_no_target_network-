# %%
# !pip install gymnasium[box2d]
import dataclasses
from ddqn_lunar_lander import *
# Out:
# Requirement already satisfied: gymnasium[box2d] in /opt/conda/envs/AI-base/lib/python3.12/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (0.0.6)
# Requirement already satisfied: box2d==2.3.10 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (2.3.10)
# Requirement already satisfied: pygame-ce>=2.1.3 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (2.5.7)
# Requirement already satisfied: swig==4.* in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (4.4.1)

# %%
cfg = DDQNConfig()
print(dataclasses.asdict(cfg))
# Out:
# {'env_id': 'LunarLander-v3', 'episodes': 500, 'max_steps': 1000, 'gamma': 0.99, 'lr': 0.001, 'batch_size': 64, 'replay_size': 100000, 'min_replay_size': 1000, 'epsilon_start': 1.0, 'epsilon_end': 0.05, 'epsilon_decay': 0.995, 'target_update_freq': 200, 'seed': 42, 'hidden_dim': 128, 'eval_episodes': 5, 'eval_seed_offset': 100000, 'render': False, 'target_network_countdown': 25, 'lr_decay_exponent': 2, 'lr_lower': 0.0001, 'save_after': 10, 'save_rate': 20, 'save_before': 1000, 'loss_threshold': 10, 'current_episode': 1, 'path': None, 'replay_buffer_path': None}

# %%
trained_agent, device, stats = train(cfg)
evaluate(trained_agent, cfg, device)
# Out:
# Episode    1/500 | Reward: -155.9735638089679 | Epsilon:  0.995
# Episode    2/500 | Reward: -170.72764221923325 | Epsilon:  0.990
# Episode    3/500 | Reward: -33.39629766199879 | Epsilon:  0.985
# Episode    4/500 | Reward: -184.50376109666385 | Epsilon:  0.980
# Episode    5/500 | Reward: -350.7362643814996 | Epsilon:  0.975
# EVAL
# [Eval] Mean reward over 5 episodes: -495.24
# Episode    6/500 | Reward: -102.57388163351825 | Epsilon:  0.970
# Episode    7/500 | Reward: -233.67013512339477 | Epsilon:  0.966
# Episode    8/500 | Reward: -65.51146645785964 | Epsilon:  0.961
# Episode    9/500 | Reward: -124.16970144989732 | Epsilon:  0.956
# Episode   10/500 | Reward: -32.011416380931806 | Epsilon:  0.951
# EVAL
# [Eval] Mean reward over 5 episodes: -495.24
# Episode   11/500 | Reward: -346.60964352750875 | Epsilon:  0.946
# Episode   12/500 | Reward: -115.93481322974789 | Epsilon:  0.942
# Episode   13/500 | Reward: -195.76633707173198 | Epsilon:  0.937
# Episode   14/500 | Reward: -85.35042437516523 | Epsilon:  0.932
# Episode   15/500 | Reward: -213.29733579605983 | Epsilon:  0.928
# EVAL
# [Eval] Mean reward over 5 episodes: -469.39
# Episode   16/500 | Reward: -103.98369062289422 | Epsilon:  0.923
# Episode   17/500 | Reward: -35.77561861205501 | Epsilon:  0.918
# Episode   18/500 | Reward: -501.31947755698764 | Epsilon:  0.914
# Episode   19/500 | Reward: -309.64896201946186 | Epsilon:  0.909
# Episode   20/500 | Reward: -164.94481253755572 | Epsilon:  0.905
# EVAL
# [Eval] Mean reward over 5 episodes: -1297.37
# {'env_id': 'LunarLander-v3', 'episodes': 500, 'max_steps': 1000, 'gamma': 0.99, 'lr': 0.001, 'batch_size': 64, 'replay_size': 100000, 'min_replay_size': 1000, 'epsilon_start': 1.0, 'epsilon_end': 0.05, 'epsilon_decay': 0.995, 'target_update_freq': 200, 'seed': 42, 'hidden_dim': 128, 'eval_episodes': 5, 'eval_seed_offset': 100000, 'render': False, 'target_network_countdown': 0, 'lr_decay_exponent': 2, 'lr_lower': 0.0001, 'save_after': 0, 'save_rate': 0, 'save_before': 0, 'loss_threshold': 10, 'current_episode': 20, 'path': 'models/LunarLander-v320.pth', 'replay_buffer_path': 'models/LunarLander-v320.replay.pkl'}
# Episode   21/500 | Reward: -130.06167579112756 | Epsilon:  0.900
# Episode   22/500 | Reward: -106.06918153878551 | Epsilon:  0.896
# Episode   23/500 | Reward: -188.7237610106531 | Epsilon:  0.891
# Episode   24/500 | Reward: -512.8117009441446 | Epsilon:  0.887
# Episode   25/500 | Reward: -374.8892798054016 | Epsilon:  0.882
# Switched to using policy network for all future estimations.
# EVAL
# [Eval] Mean reward over 5 episodes: -1311.04
# Episode   26/500 | Reward: -152.62674638552778 | Epsilon:  0.878
# Episode   27/500 | Reward: -373.5848814737998 | Epsilon:  0.873
# Episode   28/500 | Reward: -288.58454673522294 | Epsilon:  0.869
# Episode   29/500 | Reward: -314.88536570965016 | Epsilon:  0.865
# Episode   30/500 | Reward: -147.81684194782312 | Epsilon:  0.860
# EVAL
# [Eval] Mean reward over 5 episodes: -534.28
# Episode   31/500 | Reward: -228.90071555083506 | Epsilon:  0.856
# Episode   32/500 | Reward: -234.26991015879605 | Epsilon:  0.852
# Episode   33/500 | Reward: -354.53021097361307 | Epsilon:  0.848
# Episode   34/500 | Reward: -115.66251546559673 | Epsilon:  0.843
# Episode   35/500 | Reward: -312.8445758838233 | Epsilon:  0.839
# EVAL
# [Eval] Mean reward over 5 episodes: -483.00
# Episode   36/500 | Reward: -267.7678927493645 | Epsilon:  0.835
# Episode   37/500 | Reward: -210.37891775889224 | Epsilon:  0.831
# Episode   38/500 | Reward: -66.3674705652424 | Epsilon:  0.827
# Episode   39/500 | Reward: -444.0795695442811 | Epsilon:  0.822
# Episode   40/500 | Reward: -117.47412260668563 | Epsilon:  0.818
# EVAL
# [Eval] Mean reward over 5 episodes: -483.14
# {'env_id': 'LunarLander-v3', 'episodes': 500, 'max_steps': 1000, 'gamma': 0.99, 'lr': 0.001, 'batch_size': 64, 'replay_size': 100000, 'min_replay_size': 1000, 'epsilon_start': 1.0, 'epsilon_end': 0.05, 'epsilon_decay': 0.995, 'target_update_freq': 200, 'seed': 42, 'hidden_dim': 128, 'eval_episodes': 5, 'eval_seed_offset': 100000, 'render': False, 'target_network_countdown': 0, 'lr_decay_exponent': 2, 'lr_lower': 0.0001, 'save_after': 0, 'save_rate': 0, 'save_before': 0, 'loss_threshold': 10, 'current_episode': 40, 'path': 'models/LunarLander-v340.pth', 'replay_buffer_path': 'models/LunarLander-v340.replay.pkl'}
# Episode   41/500 | Reward: -52.912459651165264 | Epsilon:  0.814
# Episode   42/500 | Reward: -254.3521181469046 | Epsilon:  0.810
# Episode   43/500 | Reward: -181.76072967724832 | Epsilon:  0.806
# Episode   44/500 | Reward: -105.48369778120885 | Epsilon:  0.802
# Episode   45/500 | Reward: -133.87550106164366 | Epsilon:  0.798
# EVAL
# [Eval] Mean reward over 5 episodes: -561.69
# Episode   46/500 | Reward: -130.99555401286864 | Epsilon:  0.794
# Episode   47/500 | Reward: -187.13078475693476 | Epsilon:  0.790
# Episode   48/500 | Reward: -95.83196374371157 | Epsilon:  0.786
# Episode   49/500 | Reward: -280.65179479295966 | Epsilon:  0.782
# Episode   50/500 | Reward: -119.58675800455548 | Epsilon:  0.778
# EVAL
# [Eval] Mean reward over 5 episodes: -837.40
# Episode   51/500 | Reward: -64.18410309357745 | Epsilon:  0.774
# Episode   52/500 | Reward: -98.26377850004259 | Epsilon:  0.771
# Episode   53/500 | Reward: -153.48213882909033 | Epsilon:  0.767
# Episode   54/500 | Reward: 1.2170935765367545 | Epsilon:  0.763
# Episode   55/500 | Reward: -169.36981656747744 | Epsilon:  0.759
# EVAL
# [Eval] Mean reward over 5 episodes: -572.23
# Episode   56/500 | Reward: -38.87015536290271 | Epsilon:  0.755
# Episode   57/500 | Reward: -80.69718246698116 | Epsilon:  0.751
# Episode   58/500 | Reward: -93.20926900532575 | Epsilon:  0.748
# Episode   59/500 | Reward: -0.07237889983613854 | Epsilon:  0.744
# Episode   60/500 | Reward: -104.8316888460124 | Epsilon:  0.740
# EVAL
# [Eval] Mean reward over 5 episodes: -148.61
# {'env_id': 'LunarLander-v3', 'episodes': 500, 'max_steps': 1000, 'gamma': 0.99, 'lr': 0.001, 'batch_size': 64, 'replay_size': 100000, 'min_replay_size': 1000, 'epsilon_start': 1.0, 'epsilon_end': 0.05, 'epsilon_decay': 0.995, 'target_update_freq': 200, 'seed': 42, 'hidden_dim': 128, 'eval_episodes': 5, 'eval_seed_offset': 100000, 'render': False, 'target_network_countdown': 0, 'lr_decay_exponent': 2, 'lr_lower': 0.0001, 'save_after': 0, 'save_rate': 0, 'save_before': 0, 'loss_threshold': 10, 'current_episode': 60, 'path': 'models/LunarLander-v360.pth', 'replay_buffer_path': 'models/LunarLander-v360.replay.pkl'}
# Episode   61/500 | Reward: -113.44735226122907 | Epsilon:  0.737
# Episode   62/500 | Reward: -60.15692794581883 | Epsilon:  0.733
# Episode   63/500 | Reward: -64.48668850753907 | Epsilon:  0.729
# Episode   64/500 | Reward: -130.58820198731667 | Epsilon:  0.726
# Episode   65/500 | Reward: -54.805830033137205 | Epsilon:  0.722
# EVAL
# [Eval] Mean reward over 5 episodes: -194.39
# Episode   66/500 | Reward: -79.44147729589282 | Epsilon:  0.718
# Episode   67/500 | Reward: -64.94733079330368 | Epsilon:  0.715
# Episode   68/500 | Reward: -130.5938939491941 | Epsilon:  0.711
# Episode   69/500 | Reward: -246.39203985618843 | Epsilon:  0.708
# Episode   70/500 | Reward: -178.14910626146886 | Epsilon:  0.704
# EVAL
# [Eval] Mean reward over 5 episodes: -192.02
# Episode   71/500 | Reward: -153.80299508318723 | Epsilon:  0.701
# Episode   72/500 | Reward: -65.30045102483967 | Epsilon:  0.697
# Episode   73/500 | Reward: -27.970500180596474 | Epsilon:  0.694
