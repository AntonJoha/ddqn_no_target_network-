# %%
# !pip install gymnasium[box2d]
import dataclasses
from ddqn_lunar_lander import *
# Out:
# Requirement already satisfied: gymnasium[box2d] in /opt/conda/envs/AI-base/lib/python3.12/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (0.0.6)
# Requirement already satisfied: box2d==2.3.10 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (2.3.10)
# Requirement already satisfied: pygame-ce>=2.1.3 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (2.5.7)
# Requirement already satisfied: swig==4.* in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (4.4.1)

# %%
cfg = DDQNConfig()
print(dataclasses.asdict(cfg))
# Out:
# {'env_id': 'LunarLander-v3', 'episodes': 10000, 'max_steps': 1000, 'gamma': 0.99, 'lr': 0.001, 'batch_size': 256, 'replay_size': 100000, 'min_replay_size': 1000, 'epsilon_start': 1.0, 'epsilon_end': 0.05, 'epsilon_decay': 0.995, 'target_update_freq': 200, 'seed': 42, 'hidden_dim': 128, 'eval_episodes': 5, 'eval_seed_offset': 100000, 'render': False, 'target_network_countdown': 25, 'lr_decay_exponent': 2, 'lr_lower': 0.0001, 'reward_limit': 200.0, 'reward_limit_count': 100, 'save_after': 200, 'save_rate': 20, 'save_before': 1000, 'loss_threshold': 10, 'current_episode': 1, 'path': None, 'replay_buffer_path': None}

# %%
trained_agent, device, stats = train(cfg)
res = evaluate(trained_agent, cfg, device)
save_res(trained_agent, stats, res, cfg)
# Out:
# Episode    1/10000 | Reward: -155.9735638089679 | Epsilon:  0.995
# Episode    2/10000 | Reward: -170.72764221923325 | Epsilon:  0.990
# Episode    3/10000 | Reward: -33.39629766199879 | Epsilon:  0.985
# Episode    4/10000 | Reward: -184.50376109666385 | Epsilon:  0.980
# Episode    5/10000 | Reward: -350.7362643814996 | Epsilon:  0.975
# EVAL
# [Eval] Mean reward over 5 episodes: -495.24
# Episode    6/10000 | Reward: -102.57388163351825 | Epsilon:  0.970
# Episode    7/10000 | Reward: -233.67013512339477 | Epsilon:  0.966
# Episode    8/10000 | Reward: -65.51146645785964 | Epsilon:  0.961
# Episode    9/10000 | Reward: -124.16970144989732 | Epsilon:  0.956
# Episode   10/10000 | Reward: -32.011416380931806 | Epsilon:  0.951
# EVAL
# [Eval] Mean reward over 5 episodes: -495.24
# Episode   11/10000 | Reward: -297.83787635588254 | Epsilon:  0.946
# Episode   12/10000 | Reward: -89.96250986789065 | Epsilon:  0.942
# Episode   13/10000 | Reward: -102.94838062032318 | Epsilon:  0.937
# Episode   14/10000 | Reward: -113.23887988524194 | Epsilon:  0.932
# Episode   15/10000 | Reward: -156.63354345574655 | Epsilon:  0.928
# EVAL
# [Eval] Mean reward over 5 episodes: -1322.08
# Episode   16/10000 | Reward: -102.39739622976052 | Epsilon:  0.923
# Episode   17/10000 | Reward: -141.55276433251012 | Epsilon:  0.918
# Episode   18/10000 | Reward: -110.56202224343224 | Epsilon:  0.914
# Episode   19/10000 | Reward: -183.8540958016938 | Epsilon:  0.909
# Episode   20/10000 | Reward: -174.96812733786493 | Epsilon:  0.905
# EVAL
# [Eval] Mean reward over 5 episodes: -1317.27
