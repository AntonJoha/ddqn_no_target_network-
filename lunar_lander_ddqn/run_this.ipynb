# %%
# !pip install gymnasium[box2d]
import dataclasses
from ddqn_lunar_lander import *
# Out:
# Requirement already satisfied: gymnasium[box2d] in /opt/conda/envs/AI-base/lib/python3.12/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (0.0.6)
# Requirement already satisfied: box2d==2.3.10 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (2.3.10)
# Requirement already satisfied: pygame-ce>=2.1.3 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (2.5.7)
# Requirement already satisfied: swig==4.* in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (4.4.1)

# %%
cfg = DDQNConfig()
print(dataclasses.asdict(cfg))
# Out:
# {'env_id': 'LunarLander-v3', 'episodes': 5000, 'max_steps': 1000, 'gamma': 0.99, 'lr': 0.001, 'batch_size': 256, 'replay_size': 50000, 'min_replay_size': 1000, 'epsilon_start': 1.0, 'epsilon_end': 0.05, 'epsilon_decay': 0.997, 'target_update_freq': 200, 'seed': 467738, 'hidden_dim': 128, 'eval_episodes': 5, 'eval_seed_offset': 100000, 'render': False, 'target_network_countdown': 25, 'lr_decay_exponent': 2, 'lr_lower': 0.0001, 'reward_limit': 200.0, 'reward_limit_count': 20, 'save_after': 200, 'save_rate': 40, 'save_before': 1000, 'loss_threshold': 10, 'current_episode': 1, 'path': None, 'replay_buffer_path': None}

# %%
for i in range(5):
    cfg.seed = random.randint(0,10000) # random enough, will not collide for a low sample size
    trained_agent, device, stats = train(cfg)
    res = evaluate(trained_agent, cfg, device)
    save_res(trained_agent, stats, res, cfg)
   

    for i in range(20):
        p = f"models/LunarLander-v3_seed_{cfg.seed}_episode_{200 + 40*i}.json"
        data = None
        with open(p, "r") as f:
            data = json.load(f)
        cfg = DDQNConfig(**data)
        cfg.env_id = "LunarLander-v3"
        trained_agent, device, stats = train(cfg)
        res = evaluate(trained_agent, cfg, device)
        
        save_res(trained_agent, stats, res, cfg, str(200 + 40*i))
# Out:
# Episode    1/5000 | Reward: -109.56646061781527 | Loss: n/a | Epsilon:  0.994
# Episode    2/5000 | Reward: -118.26065385602553 | Loss: n/a | Epsilon:  0.991
# Episode    3/5000 | Reward: -105.88999933256883 | Loss: n/a | Epsilon:  0.988
# Episode    4/5000 | Reward: -96.57579195757371 | Loss: n/a | Epsilon:  0.985
# Episode    5/5000 | Reward: -180.99727825888937 | Loss: n/a | Epsilon:  0.982
# EVAL
# [Eval] Mean reward over 5 episodes: -308.17
# Episode    6/5000 | Reward: -219.5790989458101 | Loss: n/a | Epsilon:  0.979
# Episode    7/5000 | Reward: -246.25230453756407 | Loss: n/a | Epsilon:  0.976
# Episode    8/5000 | Reward: -417.76145885700936 | Loss: n/a | Epsilon:  0.973
# Episode    9/5000 | Reward: 30.85370751091827 | Loss: n/a | Epsilon:  0.970
# Episode   10/5000 | Reward: -325.82943318040395 | Loss: n/a | Epsilon:  0.967
# EVAL
# [Eval] Mean reward over 5 episodes: -308.17
# Episode   11/5000 | Reward: -88.54553080806242 | Loss: n/a | Epsilon:  0.965
# Episode   12/5000 | Reward: -87.44111542032175 | Loss: 149.5882012487828 | Epsilon:  0.962
# Episode   13/5000 | Reward: -258.4515603483562 | Loss: 138.72809199797803 | Epsilon:  0.959
# Episode   14/5000 | Reward: -286.1277702013142 | Loss: 148.66790180546897 | Epsilon:  0.956
# Episode   15/5000 | Reward: -298.35895324590945 | Loss: 136.74629407287927 | Epsilon:  0.953
# EVAL
# [Eval] Mean reward over 5 episodes: -620.47
# Episode   16/5000 | Reward: -240.0731250210335 | Loss: 137.80644013331488 | Epsilon:  0.950
# Episode   17/5000 | Reward: -325.41056540542957 | Loss: 134.7080635034813 | Epsilon:  0.947
# Episode   18/5000 | Reward: -117.88453923462602 | Loss: 131.00231787363688 | Epsilon:  0.945
# Episode   19/5000 | Reward: -299.8938400273305 | Loss: 126.9705403825511 | Epsilon:  0.942
# Episode   20/5000 | Reward: -138.73637883771087 | Loss: 123.47331907942488 | Epsilon:  0.939
# EVAL
# [Eval] Mean reward over 5 episodes: -811.13
# Episode   21/5000 | Reward: -85.64540796366546 | Loss: 125.43762234637612 | Epsilon:  0.936
# Episode   22/5000 | Reward: -433.40856455914263 | Loss: 105.9897757960904 | Epsilon:  0.933
# Episode   23/5000 | Reward: -148.8600823068474 | Loss: 114.32699135260853 | Epsilon:  0.930
# Episode   24/5000 | Reward: -160.19262516686695 | Loss: 101.55734367206179 | Epsilon:  0.928
# Episode   25/5000 | Reward: -73.05673197228256 | Loss: 89.43517568218174 | Epsilon:  0.925
# Switched to using policy network for all future estimations.
# EVAL
# [Eval] Mean reward over 5 episodes: -717.16
# Episode   26/5000 | Reward: -106.1211297417616 | Loss: 93.65204333513975 | Epsilon:  0.922
# Episode   27/5000 | Reward: -246.76745806137905 | Loss: 87.63791098523495 | Epsilon:  0.919
# Episode   28/5000 | Reward: -118.60838690345568 | Loss: 84.39057782011211 | Epsilon:  0.917
# Episode   29/5000 | Reward: -298.4542102939763 | Loss: 72.05180518892077 | Epsilon:  0.914
# Episode   30/5000 | Reward: -65.76088102100907 | Loss: 69.25349251076027 | Epsilon:  0.911
# EVAL
# [Eval] Mean reward over 5 episodes: -657.39
# Episode   31/5000 | Reward: -314.9008312167615 | Loss: 62.495019796567085 | Epsilon:  0.908
# Episode   32/5000 | Reward: -14.65115037372074 | Loss: 63.85531471996772 | Epsilon:  0.906
# Episode   33/5000 | Reward: -85.7186125403339 | Loss: 54.3156632728947 | Epsilon:  0.903
# Episode   34/5000 | Reward: -116.80145062420704 | Loss: 49.210281307257496 | Epsilon:  0.900
