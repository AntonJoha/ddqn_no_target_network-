# %%
# !pip install gymnasium[box2d]
import dataclasses
from ddqn_lunar_lander import *

# %%
cfg = DDQNConfig()
import random
cfg.seed = random.randint(0,10000) # random enough, will not collide for a low sample size

# %%
for i in range(5):
    cfg.seed = random.randint(0,10000) # random enough, will not collide for a low sample size

    trained_agent, device, stats = train(cfg)
    res = evaluate(trained_agent, cfg, device)
    save_res(trained_agent, stats, res, cfg)


    for i in range(20):
        p = f"models/LunarLander-v3_seed_{cfg.seed}_episode_{200 + 40*i}.json"
        data = None
        with open(p, "r") as f:
            data = json.load(f)
        cfg = DDQNConfig(**data)
        cfg.env_id = "LunarLander-v3"
        print(cfg.path)
        trained_agent, device, stats = train(cfg)
        res = evaluate(trained_agent, cfg, device)
    
        save_res(trained_agent, stats, res, cfg, str(200 + 40*i))
# Out:
# Episode    1/5000 | Reward: -378.5092377946646 | Loss: n/a | Epsilon:  0.984
# Episode    2/5000 | Reward: -198.68510935576435 | Loss: n/a | Epsilon:  0.981
# Episode    3/5000 | Reward: -364.91154017379364 | Loss: n/a | Epsilon:  0.978
# Episode    4/5000 | Reward: -309.7631246220112 | Loss: n/a | Epsilon:  0.975
# Episode    5/5000 | Reward: -157.779145211912 | Loss: n/a | Epsilon:  0.972
# EVAL
# [Eval] Mean reward over 5 episodes: -845.47
# Episode    6/5000 | Reward: -99.24373496143404 | Loss: n/a | Epsilon:  0.969
# Episode    7/5000 | Reward: -392.7945970368812 | Loss: n/a | Epsilon:  0.966
# Episode    8/5000 | Reward: -96.4859965365981 | Loss: n/a | Epsilon:  0.964
# Episode    9/5000 | Reward: -142.6650888924246 | Loss: n/a | Epsilon:  0.961
# Episode   10/5000 | Reward: -273.7954686255391 | Loss: 93.01565662026405 | Epsilon:  0.958
# EVAL
# [Eval] Mean reward over 5 episodes: -817.90
# ...
