# %%
# !pip install gymnasium[box2d]
import dataclasses
from ddqn_lunar_lander import *
# Out:
# /nix/store/sfvyavxai6qvzmv9p9x6mp4wwdz4v41m-bash-interactive-5.3p9/bin/bash: line 1: pip: command not found

# %%
cfg = DDQNConfig()
print(dataclasses.asdict(cfg))
# Out:
# {'env_id': 'LunarLander-v3', 'episodes': 5000, 'max_steps': 1000, 'gamma': 0.99, 'lr': 0.001, 'batch_size': 256, 'replay_size': 50000, 'min_replay_size': 1000, 'epsilon_start': 1.0, 'epsilon_end': 0.05, 'epsilon_decay': 0.997, 'target_update_freq': 200, 'seed': 4678, 'hidden_dim': 128, 'eval_episodes': 5, 'eval_seed_offset': 100000, 'render': False, 'target_network_countdown': 25, 'lr_decay_exponent': 2, 'lr_lower': 0.0001, 'reward_limit': 200.0, 'reward_limit_count': 20, 'save_after': 200, 'save_rate': 20, 'save_before': 1000, 'loss_threshold': 10, 'current_episode': 1, 'path': None, 'replay_buffer_path': None}

# %%
trained_agent, device, stats = train(cfg)
res = evaluate(trained_agent, cfg, device)
save_res(trained_agent, stats, res, cfg)

for i in range(40):
    p = f"models/LunarLander-v3{200 + 20*i}.json"
    data = None
    with open(p, "r") as f:
        data = json.load(f)
    cfg = DDQNConfig(**data)
    cfg.env_id = "LunarLander-v3"
    print(cfg.path)
    trained_agent, device, stats = train(cfg)
    res = evaluate(trained_agent, cfg, device)

    save_res(trained_agent, stats, res, cfg, str(200 + 20*i))
# Out:
# <frozen importlib._bootstrap>:488: RuntimeWarning: Your system is avx2 capable but pygame was not built with support for it. The performance of some of your blits could be adversely affected. Consider enabling compile time detection with environment variables like PYGAME_DETECT_AVX2=1 if you are compiling without cross compilation.
# /nix/store/v597gxga9la7k3myx5v2ar3msjznnnrm-python3-3.13.12-env/lib/python3.13/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# Episode    1/5000 | Reward: -319.9380303625144 | Loss: n/a | Epsilon:  0.997
# Episode    2/5000 | Reward: -131.78519618759043 | Loss: n/a | Epsilon:  0.994
# Episode    3/5000 | Reward: -56.53448482687954 | Loss: n/a | Epsilon:  0.991
# Episode    4/5000 | Reward: -264.44778022722744 | Loss: n/a | Epsilon:  0.988
# Episode    5/5000 | Reward: -76.76335185896409 | Loss: n/a | Epsilon:  0.985
# EVAL
# [Eval] Mean reward over 5 episodes: -124.74
# Episode    6/5000 | Reward: -187.31411260367508 | Loss: n/a | Epsilon:  0.982
# Episode    7/5000 | Reward: -53.03211930568378 | Loss: n/a | Epsilon:  0.979
# Episode    8/5000 | Reward: -321.77656005589154 | Loss: n/a | Epsilon:  0.976
# Episode    9/5000 | Reward: -145.7681452470268 | Loss: n/a | Epsilon:  0.973
# Episode   10/5000 | Reward: -112.76550665365127 | Loss: n/a | Epsilon:  0.970
# EVAL
# [Eval] Mean reward over 5 episodes: -124.74
