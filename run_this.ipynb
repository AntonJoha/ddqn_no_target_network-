# %%
# !pip install gymnasium[box2d]
# !mkdir models
# !mkdir output
import dataclasses
from ddqn_lunar_lander import *

# %%
cfg = DDQNConfig()
import random


cfg = DDQNConfig()

# %%
trained_agent, device, stats = train(cfg)
res = evaluate(trained_agent, cfg, device)
save_res(trained_agent, stats, res, cfg)

# %%
for i in range(5):
    cfg.seed = random.randint(0,10000) # random enough, will not collide for a low sample size
    
    trained_agent, device, stats = train(cfg)
    res = evaluate(trained_agent, cfg, device)
    save_res(trained_agent, stats, res, cfg)
    
    for i in range(17):
        p = f"models/CartPole-v1_{cfg.seed}_episode_{60 + 40*i}.json"
        data = None
        with open(p, "r") as f:
            data = json.load(f)
        cfg = DDQNConfig(**data)
        cfg.env_id = "CartPole-v1"
        print(cfg.path)
        trained_agent, device, stats = train(cfg)
        res = evaluate(trained_agent, cfg, device, )
    
        save_res(trained_agent, stats, res, cfg, str(60 + 40*i))
