# %%
# !pip install gymnasium[box2d]
# !mkdir models
# !mkdir output
import dataclasses
from ddqn_lunar_lander import *
# Out:
# Requirement already satisfied: gymnasium[box2d] in /opt/conda/envs/AI-base/lib/python3.12/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (0.0.6)
# Requirement already satisfied: box2d==2.3.10 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (2.3.10)
# Requirement already satisfied: pygame-ce>=2.1.3 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (2.5.7)
# Requirement already satisfied: swig==4.* in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (4.4.1)
# mkdir: cannot create directory ‘models’: File exists
# mkdir: cannot create directory ‘output’: File exists

# %%
trained_agent, device, stats = train(cfg)
res = evaluate(trained_agent, cfg, device)
save_res(trained_agent, stats, res, cfg)

# %%
cfg = DDQNConfig()
print(dataclasses.asdict(cfg))

paths = [f"models/CartPole-v1{60 + 20*i}.json" for i in range(35)]
# Out:
# {'env_id': 'CartPole-v1', 'episodes': 5000, 'max_steps': 1000, 'gamma': 0.99, 'lr': 0.001, 'batch_size': 256, 'replay_size': 50000, 'min_replay_size': 1000, 'epsilon_start': 1.0, 'epsilon_end': 0.05, 'epsilon_decay': 0.997, 'target_update_freq': 200, 'seed': 42, 'hidden_dim': 128, 'eval_episodes': 10, 'eval_seed_offset': 100000, 'render': False, 'target_network_countdown': 2500, 'lr_factor': 2, 'lr_lower': 0.0001, 'save_after': 50, 'save_rate': 20, 'save_before': 500, 'loss_threshold': 10, 'current_episode': 1, 'path': None, 'replay_buffer_path': None}

# %%
for i in range(35):
    p = f"models/CartPole-v1{60 + 20*i}.json"
    data = None
    with open(p, "r") as f:
        data = json.load(f)
    cfg = DDQNConfig(**data)
    cfg.env_id = "CartPole-v1"
    print(cfg.path)
    trained_agent, device, stats = train(cfg)
    res = evaluate(trained_agent, cfg, device, )

    save_res(trained_agent, stats, res, cfg, str(60 + 20*i))
# Out:
# models/CartPole-v160.pth
# Weights loaded
# Replay buffer loaded from models/CartPole-v160.replay.pkl
# Episode   60/5000 | Reward: 9.0 | Epsilon:  0.833
# EVAL
# [Eval] Mean reward over 10 episodes: 9.40
# Episode   61/5000 | Reward: 10.0 | Epsilon:  0.830
# Episode   62/5000 | Reward: 18.0 | Epsilon:  0.828
# Episode   63/5000 | Reward: 13.0 | Epsilon:  0.825
# Episode   64/5000 | Reward: 15.0 | Epsilon:  0.823
# Episode   65/5000 | Reward: 15.0 | Epsilon:  0.820
# EVAL
# [Eval] Mean reward over 10 episodes: 9.40
# Episode   66/5000 | Reward: 13.0 | Epsilon:  0.818
# Episode   67/5000 | Reward: 12.0 | Epsilon:  0.815
# Episode   68/5000 | Reward: 15.0 | Epsilon:  0.813
# Episode   69/5000 | Reward: 17.0 | Epsilon:  0.810
# Episode   70/5000 | Reward: 24.0 | Epsilon:  0.808
# EVAL
# [Eval] Mean reward over 10 episodes: 9.40
# Episode   71/5000 | Reward: 13.0 | Epsilon:  0.805
# Episode   72/5000 | Reward: 11.0 | Epsilon:  0.803
# Episode   73/5000 | Reward: 16.0 | Epsilon:  0.801
# Episode   74/5000 | Reward: 12.0 | Epsilon:  0.798
# Episode   75/5000 | Reward: 18.0 | Epsilon:  0.796
# EVAL
# [Eval] Mean reward over 10 episodes: 9.40
# Episode   76/5000 | Reward: 14.0 | Epsilon:  0.793
# Episode   77/5000 | Reward: 14.0 | Epsilon:  0.791
# Episode   78/5000 | Reward: 11.0 | Epsilon:  0.789
# Episode   79/5000 | Reward: 16.0 | Epsilon:  0.786
# Episode   80/5000 | Reward: 19.0 | Epsilon:  0.784
# EVAL
# [Eval] Mean reward over 10 episodes: 9.40
# Episode   81/5000 | Reward: 12.0 | Epsilon:  0.782
# Episode   82/5000 | Reward: 16.0 | Epsilon:  0.779
# Episode   83/5000 | Reward: 17.0 | Epsilon:  0.777
# Episode   84/5000 | Reward: 24.0 | Epsilon:  0.775
# Episode   85/5000 | Reward: 34.0 | Epsilon:  0.772
