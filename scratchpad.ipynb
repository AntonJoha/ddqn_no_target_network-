# %%
# !pip install gymnasium[box2d]
import dataclasses
from ddqn_lunar_lander import *
# Out:
# Requirement already satisfied: gymnasium[box2d] in /opt/conda/envs/AI-base/lib/python3.12/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (0.0.6)
# Requirement already satisfied: box2d==2.3.10 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (2.3.10)
# Requirement already satisfied: pygame-ce>=2.1.3 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (2.5.7)
# Requirement already satisfied: swig==4.* in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (4.4.1)

# %%
cfg = DDQNConfig()
print(dataclasses.asdict(cfg))
# Out:
# {'env_id': 'CartPole-v1', 'episodes': 100, 'max_steps': 1000, 'gamma': 0.99, 'lr': 0.001, 'batch_size': 64, 'replay_size': 100000, 'min_replay_size': 1000, 'epsilon_start': 1.0, 'epsilon_end': 0.05, 'epsilon_decay': 0.995, 'target_update_freq': 200, 'seed': 42, 'hidden_dim': 128, 'eval_episodes': 10, 'eval_seed_offset': 100000, 'render': False, 'target_network_countdown': 2500}

# %%
trained_agent, device, stats = train(cfg)
evaluate(trained_agent, cfg, device)
# Out:
# Episode    1/100 | Reward: 11.0 | Epsilon:  0.995
# Episode    2/100 | Reward: 18.0 | Epsilon:  0.990
# Episode    3/100 | Reward: 10.0 | Epsilon:  0.985
# Episode    4/100 | Reward: 15.0 | Epsilon:  0.980
# Episode    5/100 | Reward: 20.0 | Epsilon:  0.975
# EVAL
# [Eval] Mean reward over 10 episodes: 9.50
# Episode    6/100 | Reward: 21.0 | Epsilon:  0.970
# Episode    7/100 | Reward: 13.0 | Epsilon:  0.966
# Episode    8/100 | Reward: 36.0 | Epsilon:  0.961
# Episode    9/100 | Reward: 57.0 | Epsilon:  0.956
# Episode   10/100 | Reward: 22.0 | Epsilon:  0.951
# EVAL
# [Eval] Mean reward over 10 episodes: 9.50
# Episode   11/100 | Reward: 10.0 | Epsilon:  0.946
# Episode   12/100 | Reward: 30.0 | Epsilon:  0.942
# Episode   13/100 | Reward: 11.0 | Epsilon:  0.937
# Episode   14/100 | Reward: 14.0 | Epsilon:  0.932
# Episode   15/100 | Reward: 13.0 | Epsilon:  0.928
# EVAL
# [Eval] Mean reward over 10 episodes: 9.50
# Episode   16/100 | Reward: 20.0 | Epsilon:  0.923
# Episode   17/100 | Reward: 18.0 | Epsilon:  0.918
# Episode   18/100 | Reward: 15.0 | Epsilon:  0.914
# Episode   19/100 | Reward: 40.0 | Epsilon:  0.909
# Episode   20/100 | Reward: 21.0 | Epsilon:  0.905
# EVAL
# [Eval] Mean reward over 10 episodes: 9.50
# Episode   21/100 | Reward: 16.0 | Epsilon:  0.900
# Episode   22/100 | Reward: 22.0 | Epsilon:  0.896
# Episode   23/100 | Reward: 33.0 | Epsilon:  0.891
# Episode   24/100 | Reward: 34.0 | Epsilon:  0.887
# Episode   25/100 | Reward: 11.0 | Epsilon:  0.882
# EVAL
# [Eval] Mean reward over 10 episodes: 9.50
# Episode   26/100 | Reward: 10.0 | Epsilon:  0.878
# Episode   27/100 | Reward: 46.0 | Epsilon:  0.873
# Episode   28/100 | Reward: 32.0 | Epsilon:  0.869
# Episode   29/100 | Reward: 11.0 | Epsilon:  0.865
# Episode   30/100 | Reward: 11.0 | Epsilon:  0.860
# EVAL
# [Eval] Mean reward over 10 episodes: 9.50
# Episode   31/100 | Reward: 19.0 | Epsilon:  0.856
# Episode   32/100 | Reward: 30.0 | Epsilon:  0.852
# Episode   33/100 | Reward: 19.0 | Epsilon:  0.848
# Episode   34/100 | Reward: 13.0 | Epsilon:  0.843
# Episode   35/100 | Reward: 16.0 | Epsilon:  0.839
# EVAL
# [Eval] Mean reward over 10 episodes: 9.50
# Episode   36/100 | Reward: 16.0 | Epsilon:  0.835
# Episode   37/100 | Reward: 29.0 | Epsilon:  0.831
# Episode   38/100 | Reward: 23.0 | Epsilon:  0.827
# Episode   39/100 | Reward: 9.0 | Epsilon:  0.822
# Episode   40/100 | Reward: 57.0 | Epsilon:  0.818
# EVAL
# [Eval] Mean reward over 10 episodes: 9.50
# Episode   41/100 | Reward: 12.0 | Epsilon:  0.814
# Episode   42/100 | Reward: 38.0 | Epsilon:  0.810
# Episode   43/100 | Reward: 9.0 | Epsilon:  0.806
# Episode   44/100 | Reward: 21.0 | Epsilon:  0.802
# Episode   45/100 | Reward: 13.0 | Epsilon:  0.798
# EVAL
# [Eval] Mean reward over 10 episodes: 9.50
# Episode   46/100 | Reward: 20.0 | Epsilon:  0.794
# Episode   47/100 | Reward: 29.0 | Epsilon:  0.790
# Episode   48/100 | Reward: 48.0 | Epsilon:  0.786
# Episode   49/100 | Reward: 31.0 | Epsilon:  0.782
# Episode   50/100 | Reward: 34.0 | Epsilon:  0.778
# EVAL
# [Eval] Mean reward over 10 episodes: 9.30
# Episode   51/100 | Reward: 16.0 | Epsilon:  0.774
# Episode   52/100 | Reward: 22.0 | Epsilon:  0.771
# Episode   53/100 | Reward: 9.0 | Epsilon:  0.767
# Episode   54/100 | Reward: 37.0 | Epsilon:  0.763
# Episode   55/100 | Reward: 47.0 | Epsilon:  0.759
# EVAL
# [Eval] Mean reward over 10 episodes: 13.60
# Episode   56/100 | Reward: 16.0 | Epsilon:  0.755
# Episode   57/100 | Reward: 35.0 | Epsilon:  0.751
# Episode   58/100 | Reward: 15.0 | Epsilon:  0.748
# Episode   59/100 | Reward: 35.0 | Epsilon:  0.744
# Episode   60/100 | Reward: 17.0 | Epsilon:  0.740
# EVAL
# [Eval] Mean reward over 10 episodes: 15.90
# Episode   61/100 | Reward: 9.0 | Epsilon:  0.737
# Episode   62/100 | Reward: 10.0 | Epsilon:  0.733
# Episode   63/100 | Reward: 35.0 | Epsilon:  0.729
# Episode   64/100 | Reward: 12.0 | Epsilon:  0.726
# Episode   65/100 | Reward: 14.0 | Epsilon:  0.722
# EVAL
# [Eval] Mean reward over 10 episodes: 14.00
# Episode   66/100 | Reward: 10.0 | Epsilon:  0.718
# Episode   67/100 | Reward: 33.0 | Epsilon:  0.715
# Episode   68/100 | Reward: 14.0 | Epsilon:  0.711
# Episode   69/100 | Reward: 12.0 | Epsilon:  0.708
# Episode   70/100 | Reward: 21.0 | Epsilon:  0.704
# EVAL
# [Eval] Mean reward over 10 episodes: 14.40
# Episode   71/100 | Reward: 15.0 | Epsilon:  0.701
# Episode   72/100 | Reward: 18.0 | Epsilon:  0.697
# Episode   73/100 | Reward: 14.0 | Epsilon:  0.694
# Episode   74/100 | Reward: 21.0 | Epsilon:  0.690
# Episode   75/100 | Reward: 16.0 | Epsilon:  0.687
# EVAL
# [Eval] Mean reward over 10 episodes: 22.60
# Episode   76/100 | Reward: 13.0 | Epsilon:  0.683
# Episode   77/100 | Reward: 14.0 | Epsilon:  0.680
# Episode   78/100 | Reward: 24.0 | Epsilon:  0.676
# Episode   79/100 | Reward: 21.0 | Epsilon:  0.673
# Episode   80/100 | Reward: 24.0 | Epsilon:  0.670
# EVAL
# [Eval] Mean reward over 10 episodes: 14.80
# Episode   81/100 | Reward: 16.0 | Epsilon:  0.666
# Episode   82/100 | Reward: 25.0 | Epsilon:  0.663
# Episode   83/100 | Reward: 14.0 | Epsilon:  0.660
# Episode   84/100 | Reward: 14.0 | Epsilon:  0.656
# Episode   85/100 | Reward: 13.0 | Epsilon:  0.653
# EVAL
# [Eval] Mean reward over 10 episodes: 12.20
# Episode   86/100 | Reward: 14.0 | Epsilon:  0.650
# Episode   87/100 | Reward: 41.0 | Epsilon:  0.647
# Episode   88/100 | Reward: 47.0 | Epsilon:  0.643
# Episode   89/100 | Reward: 95.0 | Epsilon:  0.640
# Episode   90/100 | Reward: 54.0 | Epsilon:  0.637
# EVAL
# [Eval] Mean reward over 10 episodes: 262.90
# Episode   91/100 | Reward: 23.0 | Epsilon:  0.634
# Episode   92/100 | Reward: 14.0 | Epsilon:  0.631
# Episode   93/100 | Reward: 11.0 | Epsilon:  0.627
# Episode   94/100 | Reward: 76.0 | Epsilon:  0.624
# Episode   95/100 | Reward: 69.0 | Epsilon:  0.621
# EVAL
# [Eval] Mean reward over 10 episodes: 248.80
# Episode   96/100 | Reward: 53.0 | Epsilon:  0.618
# Episode   97/100 | Reward: 53.0 | Epsilon:  0.615
# Episode   98/100 | Reward: 85.0 | Epsilon:  0.612
# Episode   99/100 | Reward: 51.0 | Epsilon:  0.609
# Episode  100/100 | Reward: 94.0 | Epsilon:  0.606
# EVAL
# [Eval] Mean reward over 10 episodes: 199.70
# [Eval] Mean reward over 10 episodes: 199.70
# {'reward': {'mean': np.float64(199.7),
#   'var': np.float64(2085.21),
#   'list': [173.0,
#    298.0,
#    202.0,
#    164.0,
#    246.0,
#    213.0,
#    185.0,
#    137.0,
#    154.0,
#    225.0]},
#  'steps': {'mean': np.float64(199.7),
#   'var': np.float64(2085.21),
#   'list': [173, 298, 202, 164, 246, 213, 185, 137, 154, 225]}}
