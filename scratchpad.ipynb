# %%
# !pip install gymnasium[box2d]
import dataclasses
from ddqn_lunar_lander import *
# Out:
# Requirement already satisfied: gymnasium[box2d] in /opt/conda/envs/AI-base/lib/python3.12/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (0.0.6)
# Requirement already satisfied: box2d==2.3.10 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (2.3.10)
# Requirement already satisfied: pygame-ce>=2.1.3 in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (2.5.7)
# Requirement already satisfied: swig==4.* in /opt/conda/envs/AI-base/lib/python3.12/site-packages (from gymnasium[box2d]) (4.4.1)

# %%
cfg = DDQNConfig()
print(dataclasses.asdict(cfg))
# Out:
# {'env_id': 'CartPole-v1', 'episodes': 100, 'max_steps': 1000, 'gamma': 0.99, 'lr': 0.001, 'batch_size': 64, 'replay_size': 100000, 'min_replay_size': 1000, 'epsilon_start': 1.0, 'epsilon_end': 0.05, 'epsilon_decay': 0.995, 'target_update_freq': 200, 'seed': 42, 'hidden_dim': 128, 'eval_episodes': 10, 'eval_seed_offset': 100000, 'render': False, 'target_network_countdown': 2500}

# %%
trained_agent, device, stats = train(cfg)
evaluate(trained_agent, cfg, device)
# Out:
# Weights loaded
# Episode    1/100 | Reward: 11.0 | Epsilon:  0.995
# Episode    2/100 | Reward: 18.0 | Epsilon:  0.990
# Episode    3/100 | Reward: 10.0 | Epsilon:  0.985
# Episode    4/100 | Reward: 15.0 | Epsilon:  0.980
# Episode    5/100 | Reward: 20.0 | Epsilon:  0.975
# EVAL
# /opt/conda/envs/AI-base/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/conda/envs/AI-base/lib/python3.12/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# [Eval] Mean reward over 10 episodes: 55.60
# Episode    6/100 | Reward: 21.0 | Epsilon:  0.970
# Episode    7/100 | Reward: 13.0 | Epsilon:  0.966
# Episode    8/100 | Reward: 36.0 | Epsilon:  0.961
# Episode    9/100 | Reward: 39.0 | Epsilon:  0.956
# Episode   10/100 | Reward: 42.0 | Epsilon:  0.951
# EVAL
# [Eval] Mean reward over 10 episodes: 55.60
# Episode   11/100 | Reward: 11.0 | Epsilon:  0.946
# Episode   12/100 | Reward: 12.0 | Epsilon:  0.942
# Episode   13/100 | Reward: 13.0 | Epsilon:  0.937
# Episode   14/100 | Reward: 10.0 | Epsilon:  0.932
# Episode   15/100 | Reward: 10.0 | Epsilon:  0.928
# EVAL
# [Eval] Mean reward over 10 episodes: 55.60
# Episode   16/100 | Reward: 12.0 | Epsilon:  0.923
# Episode   17/100 | Reward: 12.0 | Epsilon:  0.918
# Episode   18/100 | Reward: 22.0 | Epsilon:  0.914
# Episode   19/100 | Reward: 21.0 | Epsilon:  0.909
# Episode   20/100 | Reward: 36.0 | Epsilon:  0.905
# EVAL
# [Eval] Mean reward over 10 episodes: 55.60
# {'env_id': 'CartPole-v1', 'episodes': 100, 'max_steps': 1000, 'gamma': 0.99, 'lr': 0.001, 'batch_size': 64, 'replay_size': 100000, 'min_replay_size': 1000, 'epsilon_start': 1.0, 'epsilon_end': 0.05, 'epsilon_decay': 0.995, 'target_update_freq': 200, 'seed': 42, 'hidden_dim': 128, 'eval_episodes': 10, 'eval_seed_offset': 100000, 'render': False, 'target_network_countdown': 0, 'current_episode': 20, 'save_after': 0, 'save_rate': 0, 'save_before': 0, 'path': 'models/CartPole-v120.pth'}
# Episode   21/100 | Reward: 25.0 | Epsilon:  0.900
# Episode   22/100 | Reward: 9.0 | Epsilon:  0.896
# Episode   23/100 | Reward: 18.0 | Epsilon:  0.891
# Episode   24/100 | Reward: 47.0 | Epsilon:  0.887
# Episode   25/100 | Reward: 15.0 | Epsilon:  0.882
# EVAL
# [Eval] Mean reward over 10 episodes: 55.60
# Episode   26/100 | Reward: 22.0 | Epsilon:  0.878
# Episode   27/100 | Reward: 12.0 | Epsilon:  0.873
# Episode   28/100 | Reward: 22.0 | Epsilon:  0.869
# Episode   29/100 | Reward: 26.0 | Epsilon:  0.865
# Episode   30/100 | Reward: 14.0 | Epsilon:  0.860
# EVAL
# [Eval] Mean reward over 10 episodes: 55.60
# Episode   31/100 | Reward: 21.0 | Epsilon:  0.856
# Episode   32/100 | Reward: 14.0 | Epsilon:  0.852
# Episode   33/100 | Reward: 13.0 | Epsilon:  0.848
# Episode   34/100 | Reward: 61.0 | Epsilon:  0.843
# Episode   35/100 | Reward: 18.0 | Epsilon:  0.839
# EVAL
# [Eval] Mean reward over 10 episodes: 55.60
# Episode   36/100 | Reward: 24.0 | Epsilon:  0.835
# Episode   37/100 | Reward: 21.0 | Epsilon:  0.831
# Episode   38/100 | Reward: 12.0 | Epsilon:  0.827
# Episode   39/100 | Reward: 81.0 | Epsilon:  0.822
# Episode   40/100 | Reward: 24.0 | Epsilon:  0.818
# EVAL
# [Eval] Mean reward over 10 episodes: 55.60
# {'env_id': 'CartPole-v1', 'episodes': 100, 'max_steps': 1000, 'gamma': 0.99, 'lr': 0.001, 'batch_size': 64, 'replay_size': 100000, 'min_replay_size': 1000, 'epsilon_start': 1.0, 'epsilon_end': 0.05, 'epsilon_decay': 0.995, 'target_update_freq': 200, 'seed': 42, 'hidden_dim': 128, 'eval_episodes': 10, 'eval_seed_offset': 100000, 'render': False, 'target_network_countdown': 0, 'current_episode': 40, 'save_after': 0, 'save_rate': 0, 'save_before': 0, 'path': 'models/CartPole-v140.pth'}
# Episode   41/100 | Reward: 51.0 | Epsilon:  0.814
# Episode   42/100 | Reward: 20.0 | Epsilon:  0.810
# Episode   43/100 | Reward: 57.0 | Epsilon:  0.806
# Episode   44/100 | Reward: 17.0 | Epsilon:  0.802
# Episode   45/100 | Reward: 10.0 | Epsilon:  0.798
# EVAL
# [Eval] Mean reward over 10 episodes: 14.40
# Episode   46/100 | Reward: 12.0 | Epsilon:  0.794
# Episode   47/100 | Reward: 15.0 | Epsilon:  0.790
# Episode   48/100 | Reward: 16.0 | Epsilon:  0.786
# Episode   49/100 | Reward: 30.0 | Epsilon:  0.782
# Episode   50/100 | Reward: 19.0 | Epsilon:  0.778
# EVAL
# [Eval] Mean reward over 10 episodes: 14.40
# Episode   51/100 | Reward: 16.0 | Epsilon:  0.774
# Episode   52/100 | Reward: 14.0 | Epsilon:  0.771
# Episode   53/100 | Reward: 10.0 | Epsilon:  0.767
# Episode   54/100 | Reward: 17.0 | Epsilon:  0.763
# Episode   55/100 | Reward: 16.0 | Epsilon:  0.759
# EVAL
# [Eval] Mean reward over 10 episodes: 14.80
# Episode   56/100 | Reward: 12.0 | Epsilon:  0.755
# Episode   57/100 | Reward: 18.0 | Epsilon:  0.751
# Episode   58/100 | Reward: 10.0 | Epsilon:  0.748
# Episode   59/100 | Reward: 70.0 | Epsilon:  0.744
# Episode   60/100 | Reward: 65.0 | Epsilon:  0.740
# EVAL
# [Eval] Mean reward over 10 episodes: 14.60
# {'env_id': 'CartPole-v1', 'episodes': 100, 'max_steps': 1000, 'gamma': 0.99, 'lr': 0.001, 'batch_size': 64, 'replay_size': 100000, 'min_replay_size': 1000, 'epsilon_start': 1.0, 'epsilon_end': 0.05, 'epsilon_decay': 0.995, 'target_update_freq': 200, 'seed': 42, 'hidden_dim': 128, 'eval_episodes': 10, 'eval_seed_offset': 100000, 'render': False, 'target_network_countdown': 0, 'current_episode': 60, 'save_after': 0, 'save_rate': 0, 'save_before': 0, 'path': 'models/CartPole-v160.pth'}
# Episode   61/100 | Reward: 12.0 | Epsilon:  0.737
# Episode   62/100 | Reward: 15.0 | Epsilon:  0.733
# Episode   63/100 | Reward: 29.0 | Epsilon:  0.729
# Episode   64/100 | Reward: 20.0 | Epsilon:  0.726
# Episode   65/100 | Reward: 17.0 | Epsilon:  0.722
# EVAL
# [Eval] Mean reward over 10 episodes: 14.60
# Episode   66/100 | Reward: 15.0 | Epsilon:  0.718
# Episode   67/100 | Reward: 16.0 | Epsilon:  0.715
# Episode   68/100 | Reward: 19.0 | Epsilon:  0.711
# Episode   69/100 | Reward: 15.0 | Epsilon:  0.708
# Episode   70/100 | Reward: 21.0 | Epsilon:  0.704
# EVAL
# [Eval] Mean reward over 10 episodes: 21.70
# Episode   71/100 | Reward: 22.0 | Epsilon:  0.701
# Episode   72/100 | Reward: 52.0 | Epsilon:  0.697
# Episode   73/100 | Reward: 26.0 | Epsilon:  0.694
# Episode   74/100 | Reward: 14.0 | Epsilon:  0.690
# Episode   75/100 | Reward: 23.0 | Epsilon:  0.687
# EVAL
# [Eval] Mean reward over 10 episodes: 31.00
# Episode   76/100 | Reward: 46.0 | Epsilon:  0.683
# Episode   77/100 | Reward: 21.0 | Epsilon:  0.680
# Episode   78/100 | Reward: 19.0 | Epsilon:  0.676
# Episode   79/100 | Reward: 33.0 | Epsilon:  0.673
# Episode   80/100 | Reward: 32.0 | Epsilon:  0.670
# EVAL
# [Eval] Mean reward over 10 episodes: 12.40
# {'env_id': 'CartPole-v1', 'episodes': 100, 'max_steps': 1000, 'gamma': 0.99, 'lr': 0.001, 'batch_size': 64, 'replay_size': 100000, 'min_replay_size': 1000, 'epsilon_start': 1.0, 'epsilon_end': 0.05, 'epsilon_decay': 0.995, 'target_update_freq': 200, 'seed': 42, 'hidden_dim': 128, 'eval_episodes': 10, 'eval_seed_offset': 100000, 'render': False, 'target_network_countdown': 0, 'current_episode': 80, 'save_after': 0, 'save_rate': 0, 'save_before': 0, 'path': 'models/CartPole-v180.pth'}
